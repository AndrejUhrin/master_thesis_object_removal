# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../human_validation_test_results/subset_validation.csv")

# %%
df.head()
# Out:
#                                            File name Status
# 0  1zOiN-YBZJuGozD_sJ_D8CzKRWOLakPZ2__Außenansich...   Pass
# 1  1xZcIn6HQ8ULynNjU1Mx2a6iB4ogkZc-A__Wohnzimmer.jpg   Pass
# 2  1wf4JFdtN04JnUOWMu772fkzsFpnuiApw__Wohn-_und_E...   Fail
# 3  1wf4JFdtN04JnUOWMu772fkzsFpnuiApw__Wohn-_und_E...   Pass
# 4  1wf4JFdtN04JnUOWMu772fkzsFpnuiApw__Schlafzimme...   Pass

# %%
df['Status'].value_counts()
# Out:
# Status
# Pass    72
# Fail    19
# Name: count, dtype: int64

# %%
ax = (df['Status'].value_counts().plot.bar(figsize=(8, 6), rot=0, title='Pass vs. Fail ssubset customer validation'))

ax.bar_label(ax.containers[0], label_type='edge')

ax.set(xlabel='Status', ylabel='Count')

plt.tight_layout()
plt.show()

# %%
ax = (df['Status'].value_counts().plot.pie(figsize=(8, 6), colors=plt.cm.Pastel1.colors[:2][::-1], autopct=lambda pct: f"{pct:.1f}% ({round(pct * len(df) / 100):d})", startangle=90, ylabel=''))

ax.axis('equal')               
plt.title('Pass vs. Fail subset customer validation')
plt.tight_layout()
plt.show()
